# %%
import pandas as pd

# %%
# load data into dataframe
df = pd.read_csv("data/MLINDIV_train_full.csv")
df.head()
# Out:
#         dates     times  X  Subject                 eprocs Task_type  \
# 0  2017-02-07  15:10:46  1        2          Explore-002-1         1
# 1  2017-02-07  15:20:22  2        2          Explore-002-2         2
# 2  2017-02-07  15:29:23  3        2  Test_Trials_B_1-002-1        B1
# 3  2017-02-07  15:29:23  4        2  Test_Trials_B_1-002-1        B1
# 4  2017-02-07  15:29:23  5        2  Test_Trials_B_1-002-1        B1
#
#    Procedure  Sample  objlist  PairList  ...  Nodes.S.L  Nodes.S.M.L  \
# 0        NaN     NaN      NaN       NaN  ...        NaN          NaN
# 1        NaN     NaN      NaN       NaN  ...        NaN          NaN
# 2  TrialProc     1.0     20.0       8.0  ...          S            S
# 3  TrialProc     2.0     61.0       7.0  ...          S            M
# 4  TrialProc     3.0     67.0       1.0  ...          S            M
#
#    Num.Nodes...Turns..button.presses.  Press.S.L Press.S.M.L fmv_duration  \
# 0                                 NaN        NaN         NaN          NaN
# 1                                 NaN        NaN         NaN          NaN
# 2                                 5.0          S           M       1618.0
# 3                                 8.0          S           S       1051.0
# 4                                10.0          L           M       1051.0
#
#   path_dist_trav euc_dist_trav path_efficiencies path_efficiencies_acc_only
# 0         300.75      9.839334               NaN                        NaN
# 1         285.75     13.894693               NaN                        NaN
# 2          31.25     10.854147           2.55102                        NaN
# 3          23.00     11.450982           1.00000                        NaN
# 4          22.50      2.263846           1.00000                        1.0
#
# [5 rows x 55 columns]

# %%
# define selectors to grab subsets of data
is_test = df["eprocs"].str.contains("Test")

# %%
# create animation for one path
path = df["e_paths"][2]
print(path)

start_node = df["StartAt"][2]
end_node = df["EndAt"][2]

print(start_node)
print(end_node)
# Out:
# U4 U1 R1 J1 D1 D4 D3 D2 E2 F2 F3 F4 E4 D4 D3 J3 J2 J3
# W
# N

# %%
import matplotlib.pyplot as plt

# draw maze in plt
fig, ax = plt.subplots(figsize=(6, 6))

def draw_maze(ax):
    # starting from upper left
    external_structure = [
        # upper edge
        (0, 12), (2, 12), (2, 10), (3, 10), (3, 12), (12, 12),
        # right edge
        (12, 7), (11, 7), (11, 11), (10, 11), (10, 5), (7, 5), (7, 2), (8, 2), (8, 0),
        # bottom edge
        (6, 0), (6, 1), (7, 1), (7, 1.2), (3, 1.2), (3, 1), (5.5, 1), (5.5, 0), (2, 0), (2, 1), (1, 1),
        # right edge
        (1, 5), (2.9, 5), (2.9, 4), (2, 4), (2, 2), (3, 2), (3, 9), (2, 9), (2, 7), (2.9, 7), (2.9, 6), (1, 6), (1, 11), (0, 11), (0, 12)
    ]

    internal_structures = [
        # lower middle
        [(4, 2), (6, 2), (6, 5), (4, 5), (4, 2)],
        # middle
        [(4, 11), (4, 6), (6, 6), (6, 11), (5, 11), (5, 10), (6, 10), (6, 9), (4, 9)], 
        # upper right
        [(8, 10), (7, 10), (7, 11), (9, 11), (9, 9), (7, 9), (7, 6), (9, 6), (9, 7), (8, 7)]
    ]

    structures = internal_structures + [external_structure]

    for structure in structures:
        x_values, y_values = zip(*structure) # This unzips the start and end points into two tuples
        ax.plot(x_values, y_values, color='black')

    #plot red objects now
    red_circle_locations = [(.5, 11.5), (2.5, 4.5), (2.5, 6.5), (5.5, 9.5), (7.5, 10.5), (8.5, 6.5), (11.5, 7.5), (5, .5), (6.5, .5)]
    for circle_loc in red_circle_locations:
        circle = plt.Circle(circle_loc, 0.2, color='r')
        ax.add_patch(circle)

    # set limits so that plt doesnt jiggle things when the person triangle reaches the edges
    lims = [-0.5, 12.5]
    ax.set_xlim(lims)
    ax.set_ylim(lims)

    return ax

letter_code_to_coords_nonoffset = {
    "A": (2, 12), "B": (4, 12), "C": (5, 12),
    "D": (7, 12), "E": (10, 12), "F": (12, 12),
    "G": (2, 10), "H": (4, 10), "I": (5, 10),
    "J": (7, 10), "K": (9, 10), "L": (2, 7),
    "M": (10, 9), "N": (12, 9), "O": (8, 7.5),
    "P": (2, 5), "Q": (4, 6), "R": (7, 6),
    "S": (10, 6), "T": (4, 2.2), "U": (7, 2.2),
    "V": (3, 1), "W": (8, 1), "X": (3, 2),
    "Y": (5, 1), "Z": (2, 2)
}

# add offsets
letter_code_to_coords = {k: (v[0]-.7, v[1]-.7) for k,v in letter_code_to_coords_nonoffset.items()}

def add_letters(ax, letter_code_to_coords):
    for letter, (x,y) in letter_code_to_coords.items():
        ax.text(x, y, letter, fontsize=12, color="navy")

    return ax

def add_start_end(ax, start_loc, end_loc):
    circle = plt.Circle((start_loc[0]+.15, start_loc[1]+.15), 0.5, color='g', alpha=0.2)
    ax.add_patch(circle)

    circle = plt.Circle((end_loc[0]+.15, end_loc[1]+.15), 0.5, color='y', alpha=0.2)
    ax.add_patch(circle)

    return ax    

def add_person(ax, loc, dir, correct=True):
    if correct: color="green"
    else: color="red"

    # point in direction of dir
    point1 = (loc[0] + .9 * dir[0], loc[1] + .9 * dir[1])

    # if dir is in y we gotta flare in x
    point2 = (loc[0] - .25 * dir[1], loc[1] - .25 * dir[0])
    point3 = (loc[0] + .25 * dir[1], loc[1] + .25 * dir[0])

    triangle = plt.Polygon([point1, point2, point3], color=color, alpha=.1)
    ax.add_patch(triangle)

    return ax

def add_path_trace(ax, points_traversed,correct=True):
    if correct: color="green"
    else: color="red"

    x_values, y_values = zip(*points_traversed) # This unzips the start and end points into two tuples
    ax.plot(x_values, y_values, color=color, alpha=0.02, linewidth=5)
    return ax

ax = draw_maze(ax)
ax = add_letters(ax, letter_code_to_coords)
ax = add_start_end(ax, letter_code_to_coords[start_node], letter_code_to_coords[end_node])
ax = add_person(ax, (1.5, 11.5), (0, -1))
# ax = add_path_trace(ax, [(1.5, 11.5), [2.5, 11.5]])
plt.show()

# %%
letter_code_to_coords
number_code_to_dir = {"1": (0 ,1), "2": (1, 0), "3": (0, -1), "4": (-1, 0)}

if path[-2:] == "NA": path = path[:-2]
states = path.split()

print([x[0] for x in states])
print([x[1] for x in states])

locs = [letter_code_to_coords[x[0]] for x in states]
dirs = [number_code_to_dir[x[1]] for x in states]

# cum_paths = [[]]
# for loc in locs:
#     cum_paths.append(cum_paths[-1].copy().extend(locs))

start_loc, end_loc = letter_code_to_coords[start_node], letter_code_to_coords[end_node]

# print("jsdlkf{dir}jklsdjf{dir}".format(dir="   "))
# Out:
# ['U', 'U', 'R', 'J', 'D', 'D', 'D', 'D', 'E', 'F', 'F', 'F', 'E', 'D', 'D', 'J', 'J', 'J']
# ['4', '1', '1', '1', '1', '4', '3', '2', '2', '2', '3', '4', '4', '4', '3', '3', '2', '3']

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from joblib import Parallel, delayed

def generate_image(person_loc, person_dir, i, start_loc=None, end_loc=None, path_trace=None, dir="animation_test", title=""):
    fig, ax = plt.subplots(figsize=(6, 6))
    ax = draw_maze(ax)
    ax = add_letters(ax, letter_code_to_coords)
    ax = add_person(ax, person_loc, person_dir)

    if start_loc is not None and end_loc is not None:
        ax = add_start_end(ax, start_loc, end_loc)

    if path_trace is not None and len(path_trace) > 1:
        ax = add_path_trace(ax, path_trace)
        ax = add_path_trace(ax, [path_trace[-1], person_loc])
    
    ax.set_title(title)
    fig.savefig(f'{dir}/pic{i:04d}.png')
    plt.close()

dir_to_save = "with_trace"
Parallel(n_jobs=-1)(delayed(generate_image)(loc, dir, i, start_loc=start_loc, end_loc=end_loc, path_trace=locs[:i], dir=dir_to_save) for i, (loc, dir) in enumerate(zip(locs, dirs)))

# generate_image(locs[3], dirs[3], 3, start_loc=None, end_loc=None, path_trace=locs[:3], dir=dir_to_save)

# the y overwrites automatically so ipynb doesnt hang
os.system(f'ffmpeg -y -i {dir_to_save}/pic%04d.png -vf palettegen {dir_to_save}/palette.png')
os.system(f'ffmpeg -y -framerate 5 -i {dir_to_save}/pic%04d.png -i {dir_to_save}/palette.png -lavfi paletteuse -framerate 5 {dir_to_save}/aavideo.gif')
# Out:
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 463, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "/opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/joblib/parallel.py", line 598, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/joblib/parallel.py", line 598, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/24/lp6939qs6f1d149198s_3mv40000gn/T/ipykernel_6467/3749112033.py", line 20, in generate_image
#   File "/opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/matplotlib/figure.py", line 3388, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/matplotlib/backend_bases.py", line 2218, in print_figure
#     result = print_method(
#              ^^^^^^^^^^^^^
#   File "/opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/matplotlib/backend_bases.py", line 2068, in <lambda>
#     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#                                                                  ^^^^^
#   File "/opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py", line 496, in print_png
#     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#   File "/opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py", line 445, in _print_pil
#     mpl.image.imsave(
#   File "/opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/matplotlib/image.py", line 1676, in imsave
#     image.save(fname, **pil_kwargs)
#   File "/opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/PIL/Image.py", line 2563, in save
#     fp = builtins.open(filename, "w+b")
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/abbybertics/Documents/ucsb/mazedyn/mazedyn/with_trace/pic0001.png'
# """
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 24
#      21     plt.close()
#      23 dir_to_save = "with_trace"
# ---> 24 Parallel(n_jobs=-1)(delayed(generate_image)(loc, dir, i, start_loc=start_loc, end_loc=end_loc, path_trace=locs[:i], dir=dir_to_save) for i, (loc, dir) in enumerate(zip(locs, dirs)))
#      26 # generate_image(locs[3], dirs[3], 3, start_loc=None, end_loc=None, path_trace=locs[:3], dir=dir_to_save)
#      27
#      28 # the y overwrites automatically so ipynb doesnt hang
#      29 os.system(f'ffmpeg -y -i {dir_to_save}/pic%04d.png -vf palettegen {dir_to_save}/palette.png')
#
# File /opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File /opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File /opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/joblib/parallel.py:1754, in Parallel._retrieve(self)
#    1747 while self._wait_retrieval():
#    1748
#    1749     # If the callback thread of a worker has signaled that its task
#    1750     # triggered an exception, or if the retrieval loop has raised an
#    1751     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1752     # worker traceback.
#    1753     if self._aborting:
# -> 1754         self._raise_error_fast()
#    1755         break
#    1757     # If the next job is not ready for retrieval yet, we just wait for
#    1758     # async callbacks to progress.
#
# File /opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/joblib/parallel.py:1789, in Parallel._raise_error_fast(self)
#    1785 # If this error job exists, immediately raise the error by
#    1786 # calling get_result. This job might not exists if abort has been
#    1787 # called directly or if the generator is gc'ed.
#    1788 if error_job is not None:
# -> 1789     error_job.get_result(self.timeout)
#
# File /opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/joblib/parallel.py:745, in BatchCompletionCallBack.get_result(self, timeout)
#     739 backend = self.parallel._backend
#     741 if backend.supports_retrieve_callback:
#     742     # We assume that the result has already been retrieved by the
#     743     # callback thread, and is stored internally. It's just waiting to
#     744     # be returned.
# --> 745     return self._return_or_raise()
#     747 # For other backends, the main thread needs to run the retrieval step.
#     748 try:
#
# File /opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/joblib/parallel.py:763, in BatchCompletionCallBack._return_or_raise(self)
#     761 try:
#     762     if self.status == TASK_ERROR:
# --> 763         raise self._result
#     764     return self._result
#     765 finally:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/abbybertics/Documents/ucsb/mazedyn/mazedyn/with_trace/pic0001.png'

# %%
# okay let's make one function for doing one run...

def animate_one_path(row, dir_to_save, letter_code_to_coords=letter_code_to_coords, number_code_to_dir=number_code_to_dir):
    # EXTRACT INFO FROM ROW
    path = row["e_paths"]
    is_test = "Test" in row["eprocs"]
    
    # FIRST CONVERT PATH TO COORDS
    if path[-2:] == "NA": path = path[:-2] # this happens if the test ends unsuccessfully
    states = path.split()

    # THEN GENERATE IMAGE FOR EACH STEP IN PATH
    if is_test:
        locs = [letter_code_to_coords[chr(int(row["startPosition"])+65)]] + [letter_code_to_coords[x[0]] for x in states]
        dirs = [number_code_to_dir[str(int(row["startFacing"]))]] + [number_code_to_dir[x[1]] for x in states]
    
        start_loc, end_loc = letter_code_to_coords[row["StartAt"]], letter_code_to_coords[row["EndAt"]]
        Parallel(n_jobs=-1)(delayed(generate_image)(loc, dir, i, start_loc=start_loc, end_loc=end_loc, path_trace=locs[:i], title=f'test, accuracy={row["accuracy"]}' , dir=dir_to_save) for i, (loc, dir) in enumerate(zip(locs, dirs)))
    else:

        locs = [letter_code_to_coords[x[0]] for x in states]
        dirs = [number_code_to_dir[x[1]] for x in states]

        Parallel(n_jobs=-1)(delayed(generate_image)(loc, dir, i, path_trace=locs[:i], title="explore", dir=dir_to_save) for i, (loc, dir) in enumerate(zip(locs, dirs)))

    # THEN CONVERT TO GIF
    # the y overwrites automatically so ipynb doesnt hang
    os.system(f'ffmpeg -y -i {dir_to_save}/pic%04d.png -vf palettegen {dir_to_save}/palette.png')
    os.system(f'ffmpeg -y -framerate 10 -i {dir_to_save}/pic%04d.png -i {dir_to_save}/palette.png -lavfi paletteuse -framerate 10 {dir_to_save}/aavideo.gif')

# dir_to_save = "with_trace"
# animate_one_path(df.iloc[3], dir_to_save)

# %%
explore_df = df[df["eprocs"].str.contains("Explore")]

for i, row in explore_df.iterrows():

    dir_to_save = f"animations/explore/{i}"
    os.makedirs(dir_to_save, exist_ok=True)
    animate_one_path(row, dir_to_save)
# Out:
# sh: ffmpeg: command not found
# sh: ffmpeg: command not found
# sh: ffmpeg: command not found
# sh: ffmpeg: command not found
# sh: ffmpeg: command not found
# sh: ffmpeg: command not found
# sh: ffmpeg: command not found
# sh: ffmpeg: command not found
# sh: ffmpeg: command not found
# sh: ffmpeg: command not found
# sh: ffmpeg: command not found
# sh: ffmpeg: command not found
# sh: ffmpeg: command not found
# sh: ffmpeg: command not found
# sh: ffmpeg: command not found
# sh: ffmpeg: command not found
# sh: ffmpeg: command not found
# sh: ffmpeg: command not found
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 7
#       5 dir_to_save = f"animations/explore/{i}"
#       6 os.makedirs(dir_to_save, exist_ok=True)
# ----> 7 animate_one_path(row, dir_to_save)
#
# Cell In[10], line 24, in animate_one_path(row, dir_to_save, letter_code_to_coords, number_code_to_dir)
#      21     locs = [letter_code_to_coords[x[0]] for x in states]
#      22     dirs = [number_code_to_dir[x[1]] for x in states]
# ---> 24     Parallel(n_jobs=-1)(delayed(generate_image)(loc, dir, i, path_trace=locs[:i], title="explore", dir=dir_to_save) for i, (loc, dir) in enumerate(zip(locs, dirs)))
#      26 # THEN CONVERT TO GIF
#      27 # the y overwrites automatically so ipynb doesnt hang
#      28 os.system(f'ffmpeg -y -i {dir_to_save}/pic%04d.png -vf palettegen {dir_to_save}/palette.png')
#
# File /opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File /opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File /opt/miniconda3/envs/mazedyn-test/lib/python3.11/site-packages/joblib/parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
# okay now let's try doing all paths  at the same time

def generate_multi_path_image(df, i, start_node, end_node, letter_code_to_coords=letter_code_to_coords, number_code_to_dir=number_code_to_dir, path_trace=None, dir="multi_test", title=""):
    fig, ax = plt.subplots(figsize=(6, 6))
    ax = draw_maze(ax)
    ax = add_letters(ax, letter_code_to_coords)
    ax = add_start_end(ax, letter_code_to_coords[start_node], letter_code_to_coords[end_node])

    # GO THROUGH EACH PERSON
    for _, row in df.iterrows():
        path = row["e_paths"] 
        if path[-2:] == "NA": path = path[:-2] # this happens if the test ends unsuccessfully
        
        states = path.split()

        locs = [letter_code_to_coords[start_node]] + [letter_code_to_coords[x[0]] for x in states]

        if i >= len(states): 
            if i > 0:
                ax = add_path_trace(ax, locs, correct=row["accuracy"])
            continue

        person_loc = letter_code_to_coords[states[i][0]]
        person_dir = number_code_to_dir[states[i][1]]

        ax = add_person(ax, person_loc, person_dir, correct=row["accuracy"])

        if i > 0:
            # print("adding trace?", locs)
            ax = add_path_trace(ax, locs[:i+1], correct=row["accuracy"])
    
    ax.set_title(title)
    fig.savefig(f'{dir}/pic{i:04d}.png')
    plt.close()
    
    
def animate_by_start_end(df, start_node, end_node, dir_to_save, letter_code_to_coords=letter_code_to_coords, number_code_to_dir=number_code_to_dir):
    os.makedirs(dir_to_save, exist_ok=True)

    df_this_path = df[(df["StartAt"] == start_node) & (df["EndAt"] == end_node)]
    # just to make it more tractable for now
    # df_this_path = df_this_path.iloc[:10]

    max_path_len = int(df_this_path["nodesturns_count"].max())

    # generate_multi_path_image(df_this_path, 5, start_node, end_node)
    Parallel(n_jobs=-1)(delayed(generate_multi_path_image)(df_this_path, i, start_node, end_node, dir=dir_to_save) for i in range(max_path_len))
    
    # # THEN CONVERT TO GIF
    # # the y overwrites automatically so ipynb doesnt hang
    os.system(f'ffmpeg -y -i {dir_to_save}/pic%04d.png -vf palettegen {dir_to_save}/palette.png')
    os.system(f'ffmpeg -y -framerate 5 -i {dir_to_save}/pic%04d.png -i {dir_to_save}/palette.png -lavfi paletteuse -framerate 5 {dir_to_save}/aavideo.gif')

# dir_to_save = "multi_test"
# animate_by_start_end(df, start_node="K", end_node="W", dir_to_save=dir_to_save)

# %%
for start_node, end_node in df.groupby(["StartAt", "EndAt"]).groups.keys():
      print(start_node, end_node)
      animate_by_start_end(df, start_node=start_node, end_node=end_node, dir_to_save=f'animations/test_by_start-end/{start_node+end_node}')
      # break
# Out:
# A I
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/AI/pic%04d.png':
#   Duration: 00:00:00.84, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'animations/test_by_start-end/AI/palette.png':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: png, rgba, 16x16 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 png
# [Parsed_palettegen_0 @ 0x7ff112f32440] 255(+1) colors generated out of 9028 colors; ratio=0.028245
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.89x
# video:1kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/AI/pic%04d.png':
#   Duration: 00:00:04.20, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Input #1, png_pipe, from 'animations/test_by_start-end/AI/palette.png':
#   Duration: N/A, bitrate: N/A
#     Stream #1:0: Video: png, rgba(pc), 16x16 [SAR 1:1 DAR 1:1], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (png) -> paletteuse:default
#   Stream #1:0 (png) -> paletteuse:palette
#   paletteuse -> Stream #0:0 (gif)
# Press [q] to stop, [?] for help
# [image2 @ 0x7fd08000be00] Thread message queue blocking; consider raising the thread_queue_size option (current value: 8)
# Output #0, gif, to 'animations/test_by_start-end/AI/aavideo.gif':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: gif, pal8, 600x600 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 5 fps, 100 tbn, 5 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 gif
# frame=   21 fps=0.0 q=-0.0 Lsize=     111kB time=00:00:04.01 bitrate= 227.2kbits/s speed=21.4x
# video:111kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.017562%
# A K
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/AK/pic%04d.png':
#   Duration: 00:00:00.88, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'animations/test_by_start-end/AK/palette.png':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: png, rgba, 16x16 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 png
# [Parsed_palettegen_0 @ 0x7ff27f004440] 255(+1) colors generated out of 11481 colors; ratio=0.022211
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=1.05x
# video:1kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/AK/pic%04d.png':
#   Duration: 00:00:04.40, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Input #1, png_pipe, from 'animations/test_by_start-end/AK/palette.png':
#   Duration: N/A, bitrate: N/A
#     Stream #1:0: Video: png, rgba(pc), 16x16 [SAR 1:1 DAR 1:1], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (png) -> paletteuse:default
#   Stream #1:0 (png) -> paletteuse:palette
#   paletteuse -> Stream #0:0 (gif)
# Press [q] to stop, [?] for help
# [image2 @ 0x7fb5f580be00] Thread message queue blocking; consider raising the thread_queue_size option (current value: 8)
# Output #0, gif, to 'animations/test_by_start-end/AK/aavideo.gif':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: gif, pal8, 600x600 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 5 fps, 100 tbn, 5 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 gif
# frame=   22 fps=0.0 q=-0.0 Lsize=     129kB time=00:00:04.21 bitrate= 251.8kbits/s speed=20.1x
# video:129kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.015093%
# A L
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/AL/pic%04d.png':
#   Duration: 00:00:00.84, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'animations/test_by_start-end/AL/palette.png':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: png, rgba, 16x16 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 png
# [Parsed_palettegen_0 @ 0x7fbc31704080] 255(+1) colors generated out of 6361 colors; ratio=0.040088
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=1.02x
# video:1kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/AL/pic%04d.png':
#   Duration: 00:00:04.20, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Input #1, png_pipe, from 'animations/test_by_start-end/AL/palette.png':
#   Duration: N/A, bitrate: N/A
#     Stream #1:0: Video: png, rgba(pc), 16x16 [SAR 1:1 DAR 1:1], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (png) -> paletteuse:default
#   Stream #1:0 (png) -> paletteuse:palette
#   paletteuse -> Stream #0:0 (gif)
# Press [q] to stop, [?] for help
# [image2 @ 0x7f7c72008200] Thread message queue blocking; consider raising the thread_queue_size option (current value: 8)
# Output #0, gif, to 'animations/test_by_start-end/AL/aavideo.gif':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: gif, pal8, 600x600 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 5 fps, 100 tbn, 5 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 gif
# frame=   21 fps=0.0 q=-0.0 Lsize=      97kB time=00:00:04.01 bitrate= 199.0kbits/s speed=20.4x
# video:97kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.020052%
# A N
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/AN/pic%04d.png':
#   Duration: 00:00:00.88, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'animations/test_by_start-end/AN/palette.png':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: png, rgba, 16x16 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 png
# [Parsed_palettegen_0 @ 0x7fcf53005000] 255(+1) colors generated out of 11618 colors; ratio=0.021949
# [Parsed_palettegen_0 @ 0x7fcf53005000] Dupped color: FFFFD4D4
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=1.11x
# video:1kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/AN/pic%04d.png':
#   Duration: 00:00:04.40, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Input #1, png_pipe, from 'animations/test_by_start-end/AN/palette.png':
#   Duration: N/A, bitrate: N/A
#     Stream #1:0: Video: png, rgba(pc), 16x16 [SAR 1:1 DAR 1:1], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (png) -> paletteuse:default
#   Stream #1:0 (png) -> paletteuse:palette
#   paletteuse -> Stream #0:0 (gif)
# Press [q] to stop, [?] for help
# [image2 @ 0x7fb29880be00] Thread message queue blocking; consider raising the thread_queue_size option (current value: 8)
# Output #0, gif, to 'animations/test_by_start-end/AN/aavideo.gif':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: gif, pal8, 600x600 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 5 fps, 100 tbn, 5 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 gif
# frame=   22 fps=0.0 q=-0.0 Lsize=     129kB time=00:00:04.21 bitrate= 250.3kbits/s speed=21.1x
# video:129kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.015188%
# A O
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/AO/pic%04d.png':
#   Duration: 00:00:00.88, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'animations/test_by_start-end/AO/palette.png':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: png, rgba, 16x16 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 png
# [Parsed_palettegen_0 @ 0x7f890af046c0] 255(+1) colors generated out of 12667 colors; ratio=0.020131
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.954x
# video:1kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/AO/pic%04d.png':
#   Duration: 00:00:04.40, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Input #1, png_pipe, from 'animations/test_by_start-end/AO/palette.png':
#   Duration: N/A, bitrate: N/A
#     Stream #1:0: Video: png, rgba(pc), 16x16 [SAR 1:1 DAR 1:1], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (png) -> paletteuse:default
#   Stream #1:0 (png) -> paletteuse:palette
#   paletteuse -> Stream #0:0 (gif)
# Press [q] to stop, [?] for help
# [image2 @ 0x7fe9f180be00] Thread message queue blocking; consider raising the thread_queue_size option (current value: 8)
# Output #0, gif, to 'animations/test_by_start-end/AO/aavideo.gif':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: gif, pal8, 600x600 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 5 fps, 100 tbn, 5 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 gif
# frame=   22 fps=0.0 q=-0.0 Lsize=     125kB time=00:00:04.21 bitrate= 243.7kbits/s speed=20.4x
# video:125kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.015599%
# A P
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/AP/pic%04d.png':
#   Duration: 00:00:00.84, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'animations/test_by_start-end/AP/palette.png':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: png, rgba, 16x16 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 png
# [Parsed_palettegen_0 @ 0x7fbaa9f04300] 255(+1) colors generated out of 10751 colors; ratio=0.023719
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=1.06x
# video:1kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/AP/pic%04d.png':
#   Duration: 00:00:04.20, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Input #1, png_pipe, from 'animations/test_by_start-end/AP/palette.png':
#   Duration: N/A, bitrate: N/A
#     Stream #1:0: Video: png, rgba(pc), 16x16 [SAR 1:1 DAR 1:1], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (png) -> paletteuse:default
#   Stream #1:0 (png) -> paletteuse:palette
#   paletteuse -> Stream #0:0 (gif)
# Press [q] to stop, [?] for help
# [image2 @ 0x7fe122808600] Thread message queue blocking; consider raising the thread_queue_size option (current value: 8)
# Output #0, gif, to 'animations/test_by_start-end/AP/aavideo.gif':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: gif, pal8, 600x600 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 5 fps, 100 tbn, 5 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 gif
# frame=   21 fps=0.0 q=-0.0 Lsize=     118kB time=00:00:04.01 bitrate= 241.6kbits/s speed=20.1x
# video:118kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.016521%
# A W
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/AW/pic%04d.png':
#   Duration: 00:00:00.84, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'animations/test_by_start-end/AW/palette.png':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: png, rgba, 16x16 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 png
# [Parsed_palettegen_0 @ 0x7f995ef04d40] 255(+1) colors generated out of 14114 colors; ratio=0.018067
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=1.04x
# video:1kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/AW/pic%04d.png':
#   Duration: 00:00:04.20, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Input #1, png_pipe, from 'animations/test_by_start-end/AW/palette.png':
#   Duration: N/A, bitrate: N/A
#     Stream #1:0: Video: png, rgba(pc), 16x16 [SAR 1:1 DAR 1:1], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (png) -> paletteuse:default
#   Stream #1:0 (png) -> paletteuse:palette
#   paletteuse -> Stream #0:0 (gif)
# Press [q] to stop, [?] for help
# [image2 @ 0x7fe29c80be00] Thread message queue blocking; consider raising the thread_queue_size option (current value: 8)
# Output #0, gif, to 'animations/test_by_start-end/AW/aavideo.gif':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: gif, pal8, 600x600 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 5 fps, 100 tbn, 5 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 gif
# frame=   21 fps=0.0 q=-0.0 Lsize=     134kB time=00:00:04.01 bitrate= 273.3kbits/s speed=20.7x
# video:134kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.014599%
# A Y
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/AY/pic%04d.png':
#   Duration: 00:00:00.88, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'animations/test_by_start-end/AY/palette.png':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: png, rgba, 16x16 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 png
# [Parsed_palettegen_0 @ 0x7fa095f04500] 255(+1) colors generated out of 14593 colors; ratio=0.017474
# [Parsed_palettegen_0 @ 0x7fa095f04500] Dupped color: FFFFFAFA
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=0.983x
# video:1kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/AY/pic%04d.png':
#   Duration: 00:00:04.40, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Input #1, png_pipe, from 'animations/test_by_start-end/AY/palette.png':
#   Duration: N/A, bitrate: N/A
#     Stream #1:0: Video: png, rgba(pc), 16x16 [SAR 1:1 DAR 1:1], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (png) -> paletteuse:default
#   Stream #1:0 (png) -> paletteuse:palette
#   paletteuse -> Stream #0:0 (gif)
# Press [q] to stop, [?] for help
# [image2 @ 0x7fbb6b80be00] Thread message queue blocking; consider raising the thread_queue_size option (current value: 8)
# Output #0, gif, to 'animations/test_by_start-end/AY/aavideo.gif':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: gif, pal8, 600x600 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 5 fps, 100 tbn, 5 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 gif
# frame=   22 fps=0.0 q=-0.0 Lsize=     144kB time=00:00:04.21 bitrate= 280.0kbits/s speed=20.9x
# video:144kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.013576%
# I A
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/IA/pic%04d.png':
#   Duration: 00:00:00.80, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'animations/test_by_start-end/IA/palette.png':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: png, rgba, 16x16 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 png
# [Parsed_palettegen_0 @ 0x7fae5872a1c0] 255(+1) colors generated out of 10190 colors; ratio=0.025025
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=1.18x
# video:1kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/IA/pic%04d.png':
#   Duration: 00:00:04.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Input #1, png_pipe, from 'animations/test_by_start-end/IA/palette.png':
#   Duration: N/A, bitrate: N/A
#     Stream #1:0: Video: png, rgba(pc), 16x16 [SAR 1:1 DAR 1:1], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (png) -> paletteuse:default
#   Stream #1:0 (png) -> paletteuse:palette
#   paletteuse -> Stream #0:0 (gif)
# Press [q] to stop, [?] for help
# [image2 @ 0x7fde4e80be00] Thread message queue blocking; consider raising the thread_queue_size option (current value: 8)
# Output #0, gif, to 'animations/test_by_start-end/IA/aavideo.gif':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: gif, pal8, 600x600 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 5 fps, 100 tbn, 5 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 gif
# frame=   20 fps=0.0 q=-0.0 Lsize=     121kB time=00:00:03.81 bitrate= 259.3kbits/s speed=20.9x
# video:121kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.016198%
# I K
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/IK/pic%04d.png':
#   Duration: 00:00:00.80, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'animations/test_by_start-end/IK/palette.png':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: png, rgba, 16x16 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 png
# [Parsed_palettegen_0 @ 0x7f89fc704080] 255(+1) colors generated out of 8990 colors; ratio=0.028365
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=1.09x
# video:1kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/IK/pic%04d.png':
#   Duration: 00:00:04.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Input #1, png_pipe, from 'animations/test_by_start-end/IK/palette.png':
#   Duration: N/A, bitrate: N/A
#     Stream #1:0: Video: png, rgba(pc), 16x16 [SAR 1:1 DAR 1:1], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (png) -> paletteuse:default
#   Stream #1:0 (png) -> paletteuse:palette
#   paletteuse -> Stream #0:0 (gif)
# Press [q] to stop, [?] for help
# [image2 @ 0x7fe74080be00] Thread message queue blocking; consider raising the thread_queue_size option (current value: 8)
# Output #0, gif, to 'animations/test_by_start-end/IK/aavideo.gif':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: gif, pal8, 600x600 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 5 fps, 100 tbn, 5 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 gif
# frame=   20 fps=0.0 q=-0.0 Lsize=     121kB time=00:00:03.81 bitrate= 260.5kbits/s speed=20.9x
# video:121kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.016122%
# I L
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/IL/pic%04d.png':
#   Duration: 00:00:00.80, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'animations/test_by_start-end/IL/palette.png':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: png, rgba, 16x16 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 png
# [Parsed_palettegen_0 @ 0x7fc6d3104d00] 255(+1) colors generated out of 5558 colors; ratio=0.045880
# [Parsed_palettegen_0 @ 0x7fc6d3104d00] Dupped color: FFFFFCFC
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=1.23x
# video:1kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/IL/pic%04d.png':
#   Duration: 00:00:04.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Input #1, png_pipe, from 'animations/test_by_start-end/IL/palette.png':
#   Duration: N/A, bitrate: N/A
#     Stream #1:0: Video: png, rgba(pc), 16x16 [SAR 1:1 DAR 1:1], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (png) -> paletteuse:default
#   Stream #1:0 (png) -> paletteuse:palette
#   paletteuse -> Stream #0:0 (gif)
# Press [q] to stop, [?] for help
# [image2 @ 0x7f8bef00be00] Thread message queue blocking; consider raising the thread_queue_size option (current value: 8)
# Output #0, gif, to 'animations/test_by_start-end/IL/aavideo.gif':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: gif, pal8, 600x600 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 5 fps, 100 tbn, 5 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 gif
# frame=   20 fps=0.0 q=-0.0 Lsize=      95kB time=00:00:03.81 bitrate= 205.0kbits/s speed=21.9x
# video:95kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.020492%
# I N
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/IN/pic%04d.png':
#   Duration: 00:00:00.80, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'animations/test_by_start-end/IN/palette.png':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: png, rgba, 16x16 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 png
# [Parsed_palettegen_0 @ 0x7f7de5f045c0] 255(+1) colors generated out of 8572 colors; ratio=0.029748
# [Parsed_palettegen_0 @ 0x7f7de5f045c0] Dupped color: FF090984
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=1.07x
# video:1kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/IN/pic%04d.png':
#   Duration: 00:00:04.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Input #1, png_pipe, from 'animations/test_by_start-end/IN/palette.png':
#   Duration: N/A, bitrate: N/A
#     Stream #1:0: Video: png, rgba(pc), 16x16 [SAR 1:1 DAR 1:1], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (png) -> paletteuse:default
#   Stream #1:0 (png) -> paletteuse:palette
# ...
# Output #0, image2, to 'animations/test_by_start-end/YN/palette.png':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: png, rgba, 16x16 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 png
# [Parsed_palettegen_0 @ 0x7fd8f8004680] 255(+1) colors generated out of 13247 colors; ratio=0.019250
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=1.06x
# video:1kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/YN/pic%04d.png':
#   Duration: 00:00:04.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Input #1, png_pipe, from 'animations/test_by_start-end/YN/palette.png':
#   Duration: N/A, bitrate: N/A
#     Stream #1:0: Video: png, rgba(pc), 16x16 [SAR 1:1 DAR 1:1], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (png) -> paletteuse:default
#   Stream #1:0 (png) -> paletteuse:palette
#   paletteuse -> Stream #0:0 (gif)
# Press [q] to stop, [?] for help
# [image2 @ 0x7fb88c00be00] Thread message queue blocking; consider raising the thread_queue_size option (current value: 8)
# Output #0, gif, to 'animations/test_by_start-end/YN/aavideo.gif':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: gif, pal8, 600x600 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 5 fps, 100 tbn, 5 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 gif
# frame=   20 fps=0.0 q=-0.0 Lsize=     110kB time=00:00:03.81 bitrate= 236.7kbits/s speed=20.6x
# video:110kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.017743%
# Y O
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/YO/pic%04d.png':
#   Duration: 00:00:00.80, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'animations/test_by_start-end/YO/palette.png':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: png, rgba, 16x16 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 png
# [Parsed_palettegen_0 @ 0x7fde70704b00] 255(+1) colors generated out of 12848 colors; ratio=0.019847
# [Parsed_palettegen_0 @ 0x7fde70704b00] Dupped color: FF6BA55F
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=1.07x
# video:1kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/YO/pic%04d.png':
#   Duration: 00:00:04.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Input #1, png_pipe, from 'animations/test_by_start-end/YO/palette.png':
#   Duration: N/A, bitrate: N/A
#     Stream #1:0: Video: png, rgba(pc), 16x16 [SAR 1:1 DAR 1:1], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (png) -> paletteuse:default
#   Stream #1:0 (png) -> paletteuse:palette
#   paletteuse -> Stream #0:0 (gif)
# Press [q] to stop, [?] for help
# [image2 @ 0x7fc3e100be00] Thread message queue blocking; consider raising the thread_queue_size option (current value: 8)
# Output #0, gif, to 'animations/test_by_start-end/YO/aavideo.gif':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: gif, pal8, 600x600 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 5 fps, 100 tbn, 5 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 gif
# frame=   20 fps=0.0 q=-0.0 Lsize=     112kB time=00:00:03.81 bitrate= 240.3kbits/s speed=20.7x
# video:112kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.017478%
# Y P
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/YP/pic%04d.png':
#   Duration: 00:00:00.80, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'animations/test_by_start-end/YP/palette.png':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: png, rgba, 16x16 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 png
# [Parsed_palettegen_0 @ 0x7fd0ba804780] 255(+1) colors generated out of 6129 colors; ratio=0.041605
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed= 1.2x
# video:1kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/YP/pic%04d.png':
#   Duration: 00:00:04.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Input #1, png_pipe, from 'animations/test_by_start-end/YP/palette.png':
#   Duration: N/A, bitrate: N/A
#     Stream #1:0: Video: png, rgba(pc), 16x16 [SAR 1:1 DAR 1:1], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (png) -> paletteuse:default
#   Stream #1:0 (png) -> paletteuse:palette
#   paletteuse -> Stream #0:0 (gif)
# Press [q] to stop, [?] for help
# [image2 @ 0x7ff09080be00] Thread message queue blocking; consider raising the thread_queue_size option (current value: 8)
# Output #0, gif, to 'animations/test_by_start-end/YP/aavideo.gif':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: gif, pal8, 600x600 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 5 fps, 100 tbn, 5 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 gif
# frame=   20 fps=0.0 q=-0.0 Lsize=      94kB time=00:00:03.81 bitrate= 201.6kbits/s speed=21.7x
# video:94kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.020832%
# Y W
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/YW/pic%04d.png':
#   Duration: 00:00:00.80, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to 'animations/test_by_start-end/YW/palette.png':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: png, rgba, 16x16 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 25 fps, 25 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 png
# [Parsed_palettegen_0 @ 0x7fc430804ac0] 255(+1) colors generated out of 7671 colors; ratio=0.033242
# frame=    1 fps=0.0 q=-0.0 Lsize=N/A time=00:00:00.04 bitrate=N/A speed=1.16x
# video:1kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown
# ffmpeg version 4.2.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with clang version 4.0.1 (tags/RELEASE_401/final)
#   configuration: --prefix=/Users/abbybertics/opt/anaconda3/envs/mazedyn --cc=x86_64-apple-darwin13.4.0-clang --disable-doc --enable-avresample --enable-gmp --enable-hardcoded-tables --enable-libfreetype --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame --disable-nonfree --enable-gpl --enable-gnutls --disable-openssl --enable-libopenh264 --enable-libx264
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, image2, from 'animations/test_by_start-end/YW/pic%04d.png':
#   Duration: 00:00:04.00, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 600x600 [SAR 3937:3937 DAR 1:1], 5 fps, 5 tbr, 5 tbn, 5 tbc
# Input #1, png_pipe, from 'animations/test_by_start-end/YW/palette.png':
#   Duration: N/A, bitrate: N/A
#     Stream #1:0: Video: png, rgba(pc), 16x16 [SAR 1:1 DAR 1:1], 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 (png) -> paletteuse:default
#   Stream #1:0 (png) -> paletteuse:palette
#   paletteuse -> Stream #0:0 (gif)
# Press [q] to stop, [?] for help
# [image2 @ 0x7f7dfe808e00] Thread message queue blocking; consider raising the thread_queue_size option (current value: 8)
# Output #0, gif, to 'animations/test_by_start-end/YW/aavideo.gif':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: gif, pal8, 600x600 [SAR 1:1 DAR 1:1], q=2-31, 200 kb/s, 5 fps, 100 tbn, 5 tbc (default)
#     Metadata:
#       encoder         : Lavc58.54.100 gif
# nan nan
# frame=   20 fps=0.0 q=-0.0 Lsize=      79kB time=00:00:03.81 bitrate= 169.0kbits/s speed=20.9x
# video:79kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.024858%
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 3
#       1 for start_node, end_node in df.groupby(["StartAt", "EndAt"]).groups.keys():
#       2       print(start_node, end_node)
# ----> 3       animate_by_start_end(df, start_node=start_node, end_node=end_node, dir_to_save=f'animations/test_by_start-end/{start_node+end_node}')
#       4       # break
#
# Cell In[14], line 44, in animate_by_start_end(df, start_node, end_node, dir_to_save, letter_code_to_coords, number_code_to_dir)
#      40 df_this_path = df[(df["StartAt"] == start_node) & (df["EndAt"] == end_node)]
#      41 # just to make it more tractable for now
#      42 # df_this_path = df_this_path.iloc[:10]
# ---> 44 max_path_len = int(df_this_path["nodesturns_count"].max())
#      46 # generate_multi_path_image(df_this_path, 5, start_node, end_node)
#      47 Parallel(n_jobs=-1)(delayed(generate_multi_path_image)(df_this_path, i, start_node, end_node, dir=dir_to_save) for i in range(max_path_len))
#
# ValueError: cannot convert float NaN to integer
